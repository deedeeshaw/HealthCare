# %%
import csv
import pandas as pd

# %%
health_food= pd.read_csv("static/data/health_problem.csv", dtype={'Consume':str})
# health_food["Consume"]= health_food.Consume.astype(str)
# to change use .astype() 

health_food.dtypes
# health_food
# Out:
# ID                 int64
# Health Problem    object
# Consume           object
# Avoid             object
# dtype: object

# %%
health_food.to_json("static/data/health_problem2.json", orient="records")

# %%
def problem_dd():
    problem_list = []
    with open('static/data/problem.csv') as problem_file:
        problem = csv.reader(problem_file, delimiter=',')
        next(problem, None)
        for row in problem:
            problem_list.append({'prob_id':row[0], 'prob_desc': row[1]})
        return problem_list

problem_dd()
# Out:
# [{'prob_id': '1', 'prob_desc': 'High Cholestrol'},
#  {'prob_id': '2', 'prob_desc': 'High Blood Pressure'},
#  {'prob_id': '3', 'prob_desc': 'Gout'},
#  {'prob_id': '5', 'prob_desc': 'Vitamin D Deficiency'},
#  {'prob_id': '6', 'prob_desc': 'Breast Cancer'},
#  {'prob_id': '9', 'prob_desc': 'Prostrate Cancer'},
#  {'prob_id': '12', 'prob_desc': 'Stomach Cancer'},
#  {'prob_id': '15', 'prob_desc': 'Rhematoid Arthiritis'},
#  {'prob_id': '16', 'prob_desc': 'Diabetes Type 2'},
#  {'prob_id': '18', 'prob_desc': 'Depression'},
#  {'prob_id': '27', 'prob_desc': 'Celiac Disease'},
#  {'prob_id': '28', 'prob_desc': "Crohn's Disease"},
#  {'prob_id': '34', 'prob_desc': 'Ulcers'}]

# %%
health_df = pd.read_csv("static/data/health.csv")
health = health_df.rename(columns={'All_persons': 'Total', 'Less_than_high_school': '< High School', 'High_school': "High Schhol",
                      'Some_college': 'Some College', "Less_than_18": "Still in School",
                        "Excellent_health": "Excellent Health",
                      "VG_health": "Very Good Health", "Good_health": "Good Health", "Fair_health": "Fair Health",
                      "Poor_health": "Poor Health"})
health.set_index("Year", inplace=True)

health = health.applymap('{:,}'.format)

health
# Out:
#           Total     Male   Female < High School High Schhol Some College  \
# Year
# 2016  1,617,531  688,394  929,137       204,665     422,550      818,189
# 2015  1,599,907  700,699  899,208       178,372     422,544      864,930
# 2014  1,499,365  684,561  814,804       182,245     332,551      826,382
# 2013  1,400,523  599,960  800,563       167,905     317,342      759,359
# 2012  1,350,721  612,771  737,950       164,256     369,122      676,993
# 2011  1,330,725  603,207  727,518       164,843     353,147      687,861
# 2010  1,263,419  555,977  707,442       184,437     328,109      629,346
# 2009  1,259,456  535,983  723,473       193,600     365,512      552,229
# 2008  1,148,361  492,840  655,521       175,506     325,051      527,038
# 2007  1,126,056  489,997  636,059       201,290     303,935      509,202
# 2006  1,033,056  441,099  591,958       189,977     295,284      441,837
# 2005  1,023,763  428,757  595,006       176,257     313,642      429,700
# 2004    963,882  407,946  555,936       169,945     294,014      410,103
# 2003    895,527  406,669  488,858       174,788     273,337      359,806
# 2002    810,724  351,351  459,373       179,346     243,800      302,815
#
#      Still in School Excellent Health Very Good Health Good Health  \
# Year
# 2016         158,393          217,291          389,788     496,200
# 2015         126,000          225,866          346,476     504,467
<td>115786</td>      <td>172763</td>      <td>293997</td>      <td>378721</td>      <td>244607</td>      <td>167700</td>    </tr>    <tr>      <th>7</th>      <td>2009</td>      <td>1259456</td>      <td>535983</td>      <td>723473</td>      <td>193600</td>      <td>365512</td>      <td>552229</td>      <td>143261</td>      <td>172779</td>      <td>318728</td>      <td>353914</td>      <td>253860</td>      <td>156863</td>    </tr>    <tr>      <th>8</th>      <td>2008</td>      <td>1148361</td>      <td>492840</td>      <td>655521</td>      <td>175506</td>      <td>325051</td>      <td>527038</td>      <td>114454</td>      <td>173150</td>      <td>268419</td>      <td>308818</td>      <td>224649</td>      <td>164542</td>    </tr>    <tr>      <th>9</th>      <td>2007</td>      <td>1126056</td>      <td>489997</td>      <td>636059</td>      <td>201290</td>      <td>303935</td>      <td>509202</td>      <td>102444</td>      <td>159377</td>      <td>261337</td>      <td>334567</td>      <td>212319</td>      <td>152585</td>    </tr>    <tr>      <th>10</th>      <td>2006</td>      <td>1033056</td>      <td>441099</td>      <td>591958</td>      <td>189977</td>      <td>295284</td>      <td>441837</td>      <td>98789</td>      <td>145973</td>      <td>245667</td>      <td>303455</td>      <td>188510</td>      <td>145101</td>    </tr>    <tr>      <th>11</th>      <td>2005</td>      <td>1023763</td>      <td>428757</td>      <td>595006</td>      <td>176257</td>      <td>313642</td>      <td>429700</td>      <td>100514 ...

# %%
per_person_df = pd.read_csv("static/data/per_person.csv")
per_person = per_person_df.rename(columns={'Per_person': 'Total per Person', 'per_Male': "Male", 'per_Female': "Female",
                        'per_Less_than_high_school': '< High School', 'per_High_school': "High Schhol",
                      'per_Some_college': 'Some College', "per_Less_than_18": "Still in School",
                        "per_Excellent_health": "Excellent Health",
                      "per_VG_health": "Very Good Health", "per_Good_health": "Good Health", "per_Fair_health": "Fair Health",
                      "per_Poor_health": "Poor Health"})
per_person.set_index("Year", inplace=True)

per_person
# Out:
#       Total per Person  Male  Female  < High School  High Schhol  \
# Year
# 2016                 5     4       6              6            6
# 2015                 5     4       5              5            6
# 2014                 5     4       5              5            5
# 2013                 4     4       5              5            5
# 2012                 4     4       5              5            6
# 2011                 4     4       5              5            5
# 2010                 4     4       5              5            5
# 2009                 4     4       5              5            5
# 2008                 4     3       4              4            5
# 2007                 4     3       4              5            4
# 2006                 3     3       4              4            4
# 2005                 3     3       4              4            4
# 2004                 3     3       4              4            4
# 2003                 3     3       3              4            4
# 2002                 3     2       3              4            3
#
#       Some College  Still in School  Excellent Health  Very Good Health  \
# Year
# 2016             6                2                 2                 4
# 2015             6                2                 2                 3
# 2014             6                2                 2                 4
# 2013             5                2                 2                 3
# 2012             5                2                 2                 3
# 2011             5                2                 2                 3
# 2010             5                2                 2                 3
# 2009             5                2                 2                 3
# 2008             5                2                 2                 3
# 2007             4                1                 2                 3
# 2006             4                1                 2                 2
# 2005             4                1                 1                 2
# 2004             4                1                 1                 2
# 2003             4                1                 1                 2
# 2002             3                1                 1                 2
#
#       Good Health  Fair Health  Poor Health
# Year
# 2016            6           12           23
# 2015            6           12           26
# 2014            5           12           23
# 2013            5           11           20
# 2012            5            9           22
# 2011            5           10           21
# 2010            5           10           20
# 2009            5           10           18
# 2008            4            9           18
# 2007            5            9           19
# 2006            4            8           17
# 2005            4            9           18
# 2004            4            8           16
# 2003            3            8           17
# 2002            3            7           14

# %%
per_person_html = per_person.to_html().replace('\n', '')

per_person_html
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th
<td>3</td>      <td>4</td>      <td>4</td>      <td>4</td>      <td>4</td>      <td>1</td>      <td>2</td>      <td>2</td>      <td>4</td>      <td>8</td>      <td>17</td>    </tr>    <tr>      <th>2005</th>      <td>3</td>      <td>3</td>      <td>4</td>      <td>4</td>      <td>4</td>      <td>4</td>      <td>1</td>      <td>1</td>      <td>2</td>      <td>4</td>      <td>9</td>      <td>18</td>    </tr>    <tr>      <th>2004</th>      <td>3</td>      <td>3</td>      <td>4</td>      <td>4</td>      <td>4</td>      <td>4</td>      <td>1</td>      <td>1</td>      <td>2</td>      <td>4</td>      <td>8</td>      <td>16</td>    </tr>    <tr>      <th>2003</th>      <td>3</td>      <td>3</td>      <td>3</td>      <td>4</td>      <td>4</td>      <td>4</td>      <td>1</td>      <td>1</td>      <td>2</td>      <td>3</td>      <td>8</td>      <td>17</td>    </tr>    <tr>      <th>2002</th>      <td>3</td>      <td>2</td>      <td>3</td>      <td>4</td>      <td>3</td>      <td>3</td ...

# %%
from config import api

# %%
# https://nutridigm-api-dev.azurewebsites.net/api/v1/nutridigm/topitemstoconsume?subscriptionId=e837b246-f6ab-8abe-545b-320d905f0024&problemId=35&api_key=e837b246-f6ab-8abe-545b-320d905f0024


base_url="https://nutridigm-api-dev.azurewebsites.net"
consume_url="/api/v1/nutridigm/topitemstoconsume?"
avoid_url="/api/v1/nutridigm/topitemstoavoid?"

problemId = 2

query_consume=base_url + consume_url + f'subscriptionId={api}&problemId={problemId}&api_key={api}'

query_avoid=base_url + avoid_url + f'subscriptionId={api}&problemId={problemId}&api_key={api}'

# %%
# Get the top ten items to consume
consume_food = requests.get(query_consume).json()
print(consume_food)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-c8f6ea746870> in <module>()
#       1 # Get the top ten items to consume
# ----> 2 consume_food = requests.get(query_consume).json()
#       3 print(consume_food)
#
# NameError: name 'requests' is not defined

# %%
type(consume_food)

# %%
len(consume_food)

# %%
# avoid_food= requests.get(query_avoid).json()
# print(avoid_food)

# %%
# def food(ProblemId):
#     consume_food = requests.get(query_consume).json()
#     avoid_food = requests.get(query_avoid).json()
#     return consume_food, avoid_food

# food(6)

# %%
# for c in consume_food:
    
# print(*consume_food, sep=';')

# %%
for c in consume_food:
    con =c.split('; ')
    print(con)

# %%
for c in con:
    print(c)

# %%
# for a in avoid_food:
#     avoid= a.split('; ')

# for a in avoid:
#     print(a)

# %%
def food(problemId):
    base_url="https://nutridigm-api-dev.azurewebsites.net"
    consume_url="/api/v1/nutridigm/topitemstoconsume?"
    avoid_url="/api/v1/nutridigm/topitemstoavoid?"

#     problemId = 2

    query_consume=base_url + consume_url + f'subscriptionId={api}&problemId={problemId}&api_key={api}'

    query_avoid=base_url + avoid_url + f'subscriptionId={api}&problemId={problemId}&api_key={api}'
    consume_food = requests.get(query_consume).json()
    for c in consume_food:
        consume =c.split('; ')
        for c in consume:
            
    avoid_food = requests.get(query_avoid).json()
    for a in avoid_food:
        avoid=a.split('; ')
        print(consume)
        print(avoid)
        return consume, avoid 

consume, avoid = food(16)

# %%
len(consume)
