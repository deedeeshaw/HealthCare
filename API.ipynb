# %%
import csv
from config import api
import pandas as pd
import requests

# %%
def problem_dd():
    problem_list = []
    with open('static/data/problem.csv') as problem_file:
        problem = csv.reader(problem_file, delimiter=',')
#       skip header row
        next(problem, None)
        for row in problem:
            problem_list.append({'prob_id':row[0], 'prob_desc': row[1]})
        return problem_list

problem_list = problem_dd()

# %%
print(problem_list)
# Out:
# [{'prob_id': '1', 'prob_desc': 'High Cholestrol'}, {'prob_id': '2', 'prob_desc': 'High Blood Pressure'}, {'prob_id': '3', 'prob_desc': 'Gout'}, {'prob_id': '5', 'prob_desc': 'Vitamin D Deficiency'}, {'prob_id': '6', 'prob_desc': 'Breast Cancer'}, {'prob_id': '9', 'prob_desc': 'Prostrate Cancer'}, {'prob_id': '12', 'prob_desc': 'Stomach Cancer'}, {'prob_id': '15', 'prob_desc': 'Rhematoid Arthiritis'}, {'prob_id': '16', 'prob_desc': 'Diabetes Type 2'}, {'prob_id': '18', 'prob_desc': 'Depression'}, {'prob_id': '27', 'prob_desc': 'Celiac Disease'}, {'prob_id': '28', 'prob_desc': "Crohn's Disease"}, {'prob_id': '34', 'prob_desc': 'Ulcers'}]

# %%
base_url="https://nutridigm-api-dev.azurewebsites.net"
consume_url="/api/v1/nutridigm/topitemstoconsume?"
avoid_url="/api/v1/nutridigm/topitemstoavoid?"


# Create Data Frame
problem_df = pd.DataFrame()

# Iterrate over the list problem_list
x = 1

for problem in problem_list:
    problemId=problem['prob_id']
    query_consume=base_url + consume_url + f'subscriptionId={api}&problemId={problemId}&api_key={api}'
    query_avoid=base_url + avoid_url + f'subscriptionId={api}&problemId={problemId}&api_key={api}'
    
    # Get the food data from nudrigim.org
    consume_food = requests.get(query_consume).json()
    avoid_food = requests.get(query_avoid).json()
    
    problem_df.loc[x, "ID"]= problem['prob_id']
    problem_df.loc[x, "Health Problem"]=problem['prob_desc']
    problem_df.loc[x, "Consume"] = consume_food
    problem_df.loc[x, "Avoid"] = avoid_food


    x +=1
problem_df
# Out:
#     ID        Health Problem  \
# 1    1       High Cholestrol
# 2    2   High Blood Pressure
# 3    3                  Gout
# 4    5  Vitamin D Deficiency
# 5    6         Breast Cancer
# 6    9      Prostrate Cancer
# 7   12        Stomach Cancer
# 8   15  Rhematoid Arthiritis
# 9   16       Diabetes Type 2
# 10  18            Depression
# 11  27        Celiac Disease
# 12  28       Crohn's Disease
# 13  34                Ulcers
#
#                                               Consume  \
# 1   EXERCISE; Barley, Fiber/Psyllium; Fish; Beans/...
# 2   [Green Leafy Vegetables & Sun-dried Tomatoes; ...
# 3   [Cherries & Berries; Water & Juices; Cereals; ...
# 4   [Catch some sun; Fish; Cod Liver Fish Oil; Egg...
# 5   [Broccoli, Cruciferous and Green Leafy vegetab...
# 6   [Berries & other fruits; Garlic, Onions & Toma...
# 7   [Garlic & Peas; Green tea; Cabbage Family & Gr...
# 8   [Ginger; Beans/Legumes; Berries, Plum, Pomegra...
# 9   [Exercise; Broccoli, Carrots, Potatoes & Spina...
# 10  [EXERCISE; Fish & Shellfish; Liver; Egg yolk; ...
# 11  [Papaya & other fruits; Amaranth, Buckwheat, C...
# 12  [Fruit & Vegetable Juices & Water; Smaller Foo...
# 13  [Cabbage Juice & Green Leafy Vegetables; Manuk...
#
#                                                 Avoid
# 1   Animal Fat & Lard; Margarine & Cheese; Sweets;...
# 2   [2+ alcoholic drinks/day; Sweets & Chocolate; ...
# 3   [Fish & Fish Roe; Beer & 2+ Alcoholic drinks/d...
# 4   [Obesity/Excess Weight; Processed & Cured Meat...
# 5   [Wheat/Whole-wheat; Sweets & Sugar; Pesticide-...
# 6   [Wheat, Bread & Cereals; Sweets & Sugar; Lunch...
# 7   [Wheat, Bread & Cereals; Sweets & Sugar; Game ...
# 8   [Sweets & Sugar; Nuts & Seeds; Luncheon & Cure...
# 9   [2+ alcoholic drinks/day; Sweets & Refined sug...
# 10  [2+ alcohol drinks/day; Sweets, Sugar & Corn S...
# 11  [Luncheon Meats; Barley, Bulgur, Rye, Spelt, T...
# 12  [Chicken Wings & Skin; Raw/uncooked Vegetables...
# 13  [Aspirin & other NSAID Prescription Drugs; Cho...

# %%
# Export the data into a json
problem_df.to_json("static/data/health_problem.json")

# %%
# Export the data into a csx

problem_df.set_index("ID", inplace=True)
problem_df.to_csv("static/data/health_problem.csv")
